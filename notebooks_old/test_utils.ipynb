# %%
# Notebook pour tester la lib utils.py
#test commit hsan

# %%
from utils import add_game_key, convert_date_metacritic
import pandas as pd

# %%
df = pd.read_csv("../data/vgchartz.csv", sep=",")
df = add_game_key(df)
vgchartz = df.copy()
vgchartz.head()
# Out:
#                             Name Platform   Genre Global_Sales  \
# 0  Grand Theft Auto: San Andreas      PS2  Action       20.81m
# 1             Grand Theft Auto V      PS3  Action       20.32m
# 2             Grand Theft Auto V      PS4  Action       19.39m
# 3    Grand Theft Auto: Vice City      PS2  Action       16.15m
# 4             Grand Theft Auto V     X360  Action       15.86m
#
#                        game_key
# 0  grand-theft-auto-san-andreas
# 1            grand-theft-auto-v
# 2            grand-theft-auto-v
# 3    grand-theft-auto-vice-city
# 4            grand-theft-auto-v

# %%
df = pd.read_csv("../data/metacritic.csv", sep=",")
df = add_game_key(df)
df = convert_date_metacritic(df,col_date="Year")
meta = df.copy()
meta.head()
# Out:
#                           Name     Platform  \
# 0                Full Throttle           PC
# 1  Sid Meier's Civilization II           PC
# 2                        Quake           PC
# 3                       Diablo           PC
# 4               Super Mario 64  Nintendo 64
#
#                                                Genre  Critic_Score  \
# 0                                 Adventure, General          86.0
# 1  Strategy, Turn-Based, Historic, General, Histo...          94.0
# 2  Action, Shooter, Shooter, First-Person, Sci-Fi...          94.0
# 3               Role-Playing, Action RPG, Action RPG          94.0
# 4                             Action, Platformer, 3D          94.0
#
#    User_Score               Publisher               Developer  N_proreviews  \
# 0         8.6               LucasArts               LucasArts             8
# 1         8.8              MicroProse                MPS Labs             7
# ...
