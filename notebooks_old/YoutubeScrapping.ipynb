# %%
apikey1 = 'AIzaSyBF-8YSfJToQx0oGdTuU8eFbcjdboE90kg'
apikey2 = 'AIzaSyBrFs2gDxXW_U0v2W5Cq_UMKgiMV4aiFhg'
apikey3 = 'AIzaSyDzSqZpWpgKYa0g2Ckd0FF4NJtlMXQozCc'
apikey4 = 'AIzaSyAwI1qKDBSRjRfKB0sl24s0MXUcFyCEEKc'
apikey5 = 'AIzaSyAvWP_Ti_ioDJWmOVlxu7_9TdCJ4NPIeK0'
apikey6 = 'AIzaSyBdScxg_FU1sfDrQuATtdkF0sRnbNl8JV0'
apikey7 = 'AIzaSyCOczFd9zvxsRTaxGLbb7ljEDKbBVBsSZs'
apikey8 = 'AIzaSyBKJ62oZcFm8oUYFrGSQYwnT1blz1yCMnQ'
apikey9 = 'AIzaSyClZGDbAbwQaMcPvwaLIpls330wYXi_3yY'
apikey10 = 'AIzaSyDZwS2bpqRmKMfZm6LChG9zXJMunEO6Tbg'
#apikey3,apikey4,apikey5,apikey6,apikey7,

apikeys = [apikey1,apikey2,apikey3,apikey4,apikey5,apikey6,apikey7,apikey8,apikey9,apikey10]

channelid = 'UCKy1dAqELo0zrOtPkf0eTMw'
IGN_id = 'UCKy1dAqELo0zrOtPkf0eTMw'

apikeys
# Out:
# ['AIzaSyBF-8YSfJToQx0oGdTuU8eFbcjdboE90kg',
#  'AIzaSyBrFs2gDxXW_U0v2W5Cq_UMKgiMV4aiFhg',
#  'AIzaSyDzSqZpWpgKYa0g2Ckd0FF4NJtlMXQozCc',
#  'AIzaSyAwI1qKDBSRjRfKB0sl24s0MXUcFyCEEKc',
#  'AIzaSyAvWP_Ti_ioDJWmOVlxu7_9TdCJ4NPIeK0',
#  'AIzaSyBdScxg_FU1sfDrQuATtdkF0sRnbNl8JV0',
#  'AIzaSyCOczFd9zvxsRTaxGLbb7ljEDKbBVBsSZs',
#  'AIzaSyBKJ62oZcFm8oUYFrGSQYwnT1blz1yCMnQ',
#  'AIzaSyClZGDbAbwQaMcPvwaLIpls330wYXi_3yY',
#  'AIzaSyDZwS2bpqRmKMfZm6LChG9zXJMunEO6Tbg']

# %%
from googleapiclient.discovery import build
import googleapiclient.errors
import pandas as pd
import numpy as np

# %%
def getIGNvideoid(channelid,topic,apikey):


    api_service_name = "youtube"
    api_version = "v3"
    
    youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey = apikey)

    request = youtube.search().list(
        part="snippet",
        channelId=channelid,
        maxResults=1,
        q=topic
    
    )
    response = request.execute()

    return(response['items'][0]['id']['videoId'])

# %%
def getstatsfromVideoId(videoid,apikey):
    res = []
    api_service_name = "youtube"
    api_version = "v3"
    

  
    youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey = apikey)

    request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id= videoid
    )
    response = request.execute()

    res.append(response['items'][0]['statistics'])
    res.append(response['items'][0]['snippet']['title'])
    res.append(response['items'][0]['snippet']['description'])
    res.append(response['items'][0]['snippet']['publishedAt'])


    return res

# %%
request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id= videoid
    )
response = request.execute()

print(response['items'][0]['snippet']['title'])
# Out:
# Pokemon Red & Blue - IGN Plays

# %%
response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '68uDzkqOC-wqWBFUzUmBbZf_OSY',
#  'items': [{'kind': 'youtube#video',
#    'etag': '_kLE0I1l_q4rmzTsaWH6ZhWguwU',
#    'id': 'aZsE76etD4I',
#    'snippet': {'publishedAt': '2014-09-18T20:40:22Z',
#     'channelId': 'UCKy1dAqELo0zrOtPkf0eTMw',
#     'title': 'Destiny Review',
#     'description': "At long last, IGN's final verdict on Bungie's ambitious shooter is here. See what we thought of Destiny.\n\n------------------------------\xad----\nFollow IGN for more!\n------------------------------\xad----\n\nYOUTUBE: https://www.youtube.com/user/ignentertainment?sub_confirmation=1\nIGN OFFICIAL APP: http://www.ign.com/mobile\nFACEBOOK: https://www.facebook.com/ign\nTWITTER: https://twitter.com/ign\nINSTAGRAM: https://instagram.com/igndotcom/?hl=en\nWEBSITE: http://www.ign.com/\nGOOGLE+: https://plus.google.com/+IGN",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aZsE76etD4I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/aZsE76etD4I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/aZsE76etD4I/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/aZsE76etD4I/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/aZsE76etD4I/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'IGN',
#     'tags': ['ign-game-reviews',
#      'none',
#      'Xbox One',
#      'Xbox 360',
#      'game reviews',
#      'Destiny',
#      'PlayStation 3',
#      'PlayStation 4',
#      'games',
#      'ign game reviews',
#      'Review'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Destiny Review',
#      'description': "At long last, IGN's final verdict on Bungie's ambitious shooter is here. See what we thought of Destiny.\n\n------------------------------\xad----\nFollow IGN for more!\n------------------------------\xad----\n\nYOUTUBE: https://www.youtube.com/user/ignentertainment?sub_confirmation=1\nIGN OFFICIAL APP: http://www.ign.com/mobile\nFACEBOOK: https://www.facebook.com/ign\nTWITTER: https://twitter.com/ign\nINSTAGRAM: https://instagram.com/igndotcom/?hl=en\nWEBSITE: http://www.ign.com/\nGOOGLE+: https://plus.google.com/+IGN"}},
#    'contentDetails': {'duration': 'PT7M56S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '1561205',
#     'likeCount': '14591',
#     'favoriteCount': '0',
#     'commentCount': '5096'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
df  = pd.read_csv('vgnew12.csv')

# %%
df['Name'][100:200]
# Out:
# 100    The Legend of Zelda: Twilight Princess
# 101                 Call of Duty: Black Ops 3
# 102                                Just Dance
# 103                             Battlefield 3
# 104                Need for Speed Underground
#                         ...
# 195                            Guitar Hero II
# 196                           Resident Evil 5
# 197                        Grand Theft Auto V
# 198       Grand Theft Auto: Vice City Stories
# 199                            FIFA Soccer 11
# Name: Name, Length: 100, dtype: object

# %%
def ytenrichDf(df,channelid,apikeys):
    n=0
    k = 90
    l = 0
    viewcount1 = []
    likecount1 = []
    commentcount1 = []
    videotitle1 = []
    published1 = []
    description1 = []
    apikey = apikeys[n]
    
    while k < 1100:   
        for i,j in zip(df['Name'][l:k],df['Rank'][l:k]):
            print(j)
        
            topic = i+' review'
            videoid = getIGNvideoid(channelid,topic,apikey)
            a = getstatsfromVideoId(videoid,apikey)
            viewcount = a[0]['viewCount']
            likecount = a[0]['likeCount']
            commentcount = a[0]['commentCount']
            videotitle = a[1]
            published = a[3]
            description = a[2]
    
            viewcount1.append(viewcount)
            likecount1.append(likecount)
            commentcount1.append(commentcount)
            videotitle1.append(videotitle)
            published1.append(published)
            description1.append(description)
        k+=99
        l+=99
        n+=1
        apikey = apikeys[n]
    
    return(viewcount1 ,likecount1,commentcount1 ,videotitle1 ,published1, description1, j ,i)

# %%
n=0
k = 2193+92
l = 2193
viewcount1 = []
likecount1 = []
commentcount1 = []
videotitle1 = []
published1 = []
description1 = []
apikey = apikeys[n]
    
while k < 2421 and n < 10:   
    for i,j in zip(df['Name'][l:k],df['Rank'][l:k]):
        print(i,j)
        
        topic = i+' review'
        try : 
            videoid = getIGNvideoid(channelid,topic,apikey)
            a = getstatsfromVideoId(videoid,apikey)
            viewcount = a[0]['viewCount']
            likecount = a[0]['likeCount']
            commentcount = a[0]['commentCount']
            videotitle = a[1]
            published = a[3]
            description = a[2]
    
            viewcount1.append(viewcount)
            likecount1.append(likecount)
            commentcount1.append(commentcount)
            videotitle1.append(videotitle)
            published1.append(published)
            description1.append(description)
        except IndexError:
            viewcount1.append(np.nan)
            likecount1.append(np.nan)
            commentcount1.append(np.nan)
            videotitle1.append(np.nan)
            published1.append(np.nan)
            description1.append(np.nan)
            
    k+=92
    l+=92
    n+=1
    apikey = apikeys[n]
# Out:
# IHRA Drag Racing 2 1502
# The Beatles: Rock Band 1503
# Tekken 6 1504
# [Prototype] 1505
# Deal or No Deal 1506
# Madagascar 1507
# Rugrats Studio Tour 1508
# LEGO Battles 1509
# Pitfall II: Lost Caverns 1510
# Turok: Evolution 1511
# High School Musical 3: Senior Year DANCE! 1512
# Gold's Gym: Cardio Workout 1513
# Burnout 3: Takedown 1514
# Adventure 1515
# Yu-Gi-Oh! The Sacred Cards 1516
# Crysis 2 1517
# NBA Live 07 1518
# Saints Row IV 1519
# SingStar '80s 1520
# EA Playground 1521
# Test Drive 5 1522
# Romancing SaGa 3 1523
# EA Sports Active 2 1524
# Digimon World 1525
# Rise of the Tomb Raider 1526
# Need for Speed Carbon 1527
# Yoshi's Woolly World 1528
# Mega Man Battle Network 3 Blue / White Version 1529
# FIFA Street 1530
# Resident Evil Zero 1531
# Need for Speed: Most Wanted 1532
# Tom Clancy's Rainbow Six: Siege 1533
# Pirates of the Caribbean: The Curse of the Black Pearl 1534
# Transformers 1535
# Guitar Hero: Aerosmith 1536
# Mystery Case Files: MillionHeir 1537
# Valkyria Chronicles 1538
# Midnight Club 3: DUB Edition (America weekly sales) 1539
# Champions of Norrath 1540
# Watch Dogs 1541
# Imagine: Wedding Designer 1542
# Metal Gear Solid V: Ground Zeroes 1543
# Yakuman 1544
# Assassin's Creed Syndicate 1545
# Army Men 3D 1546
# WWE '13 1547
# Twisted Metal 4 1548
# Manhunt 1549
# Kid Icarus: Uprising 1550
# Silent Hill 2 1551
# Tomb Raider: Underworld 1552
# Castlevania: Symphony of the Night 1553
# The Sims 2: Nightlife 1554
# LEGO Batman: The Videogame 1555
# Road Rash 1556
# Pokemon Mystery Dungeon: Gates to Infinity 1557
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /var/folders/yj/cg_pry110q54bhv3x3b1y2cw0000gn/T/ipykernel_1286/3381496708.py in <module>
#      16         topic = i+' review'
#      17         try :
# ---> 18             videoid = getIGNvideoid(channelid,topic,apikey)
#      19             a = getstatsfromVideoId(videoid,apikey)
#      20             viewcount = a[0]['viewCount']
#
# /var/folders/yj/cg_pry110q54bhv3x3b1y2cw0000gn/T/ipykernel_1286/3648007665.py in getIGNvideoid(channelid, topic, apikey)
#      15
#      16     )
# ---> 17     response = request.execute()
#      18
#      19     return(response['items'][0]['id']['videoId'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     129                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     130                     logger.warning(message)
# --> 131             return wrapped(*args, **kwargs)
#     132
#     133         return positional_wrapper
#
# ~/opt/anaconda3/lib/python3.7/site-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     929             method=str(self.method),
#     930             body=self.body,
# --> 931             headers=self.headers,
#     932         )
#     933
#
# ~/opt/anaconda3/lib/python3.7/site-packages/googleapiclient/http.py in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     219         if exception:
#     220             if retry_num == num_retries:
# --> 221                 raise exception
#     222             else:
#     223                 continue
#
# ~/opt/anaconda3/lib/python3.7/site-packages/googleapiclient/http.py in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     188         try:
#     189             exception = None
# --> 190             resp, content = http.request(uri, method, *args, **kwargs)
#     191         # Retry on SSL errors and socket timeout errors.
#     192         except _ssl_SSLError as ssl_error:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/httplib2/__init__.py in request(self, uri, method, body, headers, redirections, connection_type)
#    1700                 else:
#    1701                     (response, content) = self._request(
# -> 1702                         conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#    1703                     )
#    1704         except Exception as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/httplib2/__init__.py in _request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1419             auth.request(method, request_uri, headers, body)
#    1420
# -> 1421         (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1422
#    1423         if auth:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/httplib2/__init__.py in _conn_request(self, conn, request_uri, method, body, headers)
#    1371                 pass
#    1372             try:
# -> 1373                 response = conn.getresponse()
#    1374             except (http.client.BadStatusLine, http.client.ResponseNotReady):
#    1375                 # If we get a BadStatusLine on the first try then that means
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# timeout: The read operation timed out

# %%
vc = viewcount1
lc = likecount1
cm = commentcount1
vt = videotitle1
pb = published1
des = description1

# %%
2193+len(vt)
# Out:
# 2194

# %%
df['viewconut'][2193:2194] = vc
df['likecount'][1500:2194]  = lc
df['commentcount'][1500:2194]  = cm
df['videotitle'][1500:2194] = vt
df['published'][1500:2194]  = pb
df['description'][1500:2194]  = des
# Out:
# /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.to_csv('vgnew13.csv')
df2 = df.drop('description',1)
df2.to_csv('vgnew_nodesc3.csv')
# Out:
# /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
df.iloc[699,:]
# Out:
# Unnamed: 0                                                    699
# Unnamed: 0.1                                                  699
# Rank                                                          701
# Name                                          Yokai Watch Busters
# Platform                                                      3DS
# Year                                                       2015.0
# Genre                                                      Action
# Publisher                                                 Level 5
# NA_Sales                                                      0.0
# EU_Sales                                                      0.0
# JP_Sales                                                     2.28
# Other_Sales                                                   0.0
# Global_Sales                                                 2.28
# multiplayer                                                   NaN
# singleplayer                                                  NaN
# viewconut                                                   40862
# likecount                                                     613
# commentcount                                                  152
# videotitle            8 Minutes of Yo-kai Watch Blasters Gameplay
# published                                    2018-07-13T23:30:01Z
# description     Jibanyan and crew take on the second boss of Y...
# Name: 699, dtype: object
